# %%
# %run Synapse_automation_MLIs_PCs.ipynb
# !pip install gspread-dataframe
import gspread_dataframe as gspread
# Out:
# ...
#
# cc_0: {'cell_type': 'cc', 'xyz': (716736, 1384080, 6480), 'tags': ['cc'], 'finished': False}
# gcl_0: {'cell_type': 'interneuron', 'xyz': (1082368, 1712000, 8840), 'tags': [], 'finished': False}
# gcl_1: {'cell_type': 'interneuron', 'xyz': (1039408, 1712352, 35080), 'tags': [], 'finished': False}
# gcl_10: {'cell_type': 'interneuron', 'xyz': (1768800, 1661712, 44440), 'tags': [], 'finished': False}
# gcl_11: {'cell_type': 'interneuron', 'xyz': (2002144, 1763760, 9800), 'tags': [], 'finished': False}
# gcl_12: {'cell_type': 'interneuron', 'xyz': (1997584, 1711344, 37880), 'tags': [], 'finished': False}
# gcl_13: {'cell_type': 'interneuron', 'xyz': (1919744, 1663472, 46760), 'tags': ['golgi'], 'finished': True}
# gcl_14: {'cell_type': 'interneuron', 'xyz': (2083760, 1731152, 21240), 'tags': ['golgi'], 'finished': False}
# gcl_15: {'cell_type': 'interneuron', 'xyz': (2265920, 1630128, 43080), 'tags': [], 'finished': False}
# ...

# %% [markdown]
# # Connections Onto pc_21

# %%
neurons_to_pc_21 = all_connections_to('pc_21', True, 'mli1')
# Out:
# Number of connections: 975

# %%
def list_of_neurons(all_neurons):
    lo_neurons = []
    for neurons in all_neurons:
        lo_neurons.append(neurons[0])
        
    filtered = []
    for item in lo_neurons:
        if item not in filtered:
            filtered.append(item)
            
    return filtered


        
filtered_to_pc_21 = list_of_neurons(neurons_to_pc_21)
# print(type(filtered_to_pc_21))

# %%
check_all_connects(filtered_to_pc_21, 'pc_21')
# Out:
# ('interneuron_116', 'pc_21', {'xyz': (123964.0, 67184.0, 206.0), 'area': 0.0570670612507669})
# ('interneuron_116', 'pc_21', {'xyz': (124088.0, 68808.0, 211.0), 'area': 0.2827969435726292})
# ('interneuron_116', 'pc_21', {'xyz': (123992.0, 66380.0, 245.0), 'area': 0.059624344562854766})
# ('interneuron_116', 'pc_21', {'xyz': (123836.0, 65640.0, 257.0), 'area': 0.2640138137905266})
# ('interneuron_116', 'pc_21', {'xyz': (125396.0, 77476.0, 301.0), 'area': 0.015406781148651344})
# ('interneuron_116', 'pc_21', {'xyz': (125040.0, 73824.0, 304.0), 'area': 0.1370217947066529})
# ('interneuron_116', 'pc_21', {'xyz': (125920.0, 64732.0, 311.0), 'area': 0.1361556595727705})
# ('interneuron_116', 'pc_21', {'xyz': (125908.0, 64808.0, 316.0), 'area': 0.08178471873844974})
# ('interneuron_116', 'pc_21', {'xyz': (125340.0, 75436.0, 324.0), 'area': 0.229854635317042})
# ('interneuron_116', 'pc_21', {'xyz': (125880.0, 64704.0, 331.0), 'area': 0.0851659993851048})
# ...

# %%
# Returns type of cell and number of times it connects with possible_connection
def put_num_connections_xl_helper(name_neuron, possible_connection, graph=G):
    
    list(graph.out_edges(name_neuron, data=True))
    connects = list(graph.out_edges(name_neuron, data=True))
    counter = 0
    type_num = []
    for connection in connects:
            if (connection[1] == possible_connection):
                counter += 1   
    type_num = [name_neuron, counter]
    return type_num


def put_num_connections_xl(neurons, possible_connection):
    update_dict()
    whole_list = []
    single_list = []
    index = [0] * len(neurons)
    
    # puts all individual connection counts into a larger list
    for i, neuron in enumerate(neurons):
        single_list = put_num_connections_xl_helper(neuron, possible_connection)
        index[i] = i
        whole_list.append(single_list)
    return whole_list

def script_for_num_connects(target, filter_bool, cell_type='mli'):
    neurons_to_target = all_connections_to(target, filter_bool, cell_type)
    filtered_to_target = list_of_neurons(neurons_to_target)
    num_connects = put_num_connections_xl(filtered_to_target, target)
    workbook = xl.load_workbook(r'C:\Users\regehr2\Downloads\test-book.xlsx')
    sheet = workbook.active
    row_number, col_number = 1, 7
    sheet.cell(row=row_number, column=col_number, value='Neuron_ID')
    sheet.cell(row=row_number, column=col_number + 1, value="Cell Type")
    sheet.cell(row=row_number, column=col_number + 2, value='# Connects')
    row_number += 1
    
    for connect in num_connects: 
            sheet.cell(row=row_number, column=col_number, value=connect[0])
            sheet.cell(row=row_number, column=col_number + 1, value=CellType_dict.get(connect[0]))
            sheet.cell(row=row_number, column=col_number + 2, value=connect[1])
            row_number += 1
    sheet.cell(row=row_number+ 1, column=col_number, value=target)
    workbook.save(r'C:\Users\regehr2\Downloads\test-book.xlsx')

# %%
def script_for_all_connects(target, filter_bool=False, cell_type='mli'):
    neurons_to_target = all_connections_to(target, filter_bool, cell_type)
    filtered_to_target = list_of_neurons(neurons_to_target)
    automated_connections_list(filtered_to_target, target, r'C:\Users\regehr2\Downloads\test-book.xlsx')
    script_for_num_connects(target, filter_bool, cell_type)
    put_num_connections_df_violin(filtered_to_target, target, 'Cell Type', 'Connections')

# %%
script_for_all_connects('pc_21', True)
# Out:
# Number of connections: 984
# Number of connections: 984

# %%
# # Returns type of cell and number of times it connects with possible_connection
# def put_num_connections_xl_helper(name_neuron, possible_connection, graph=G):
    
#     list(graph.out_edges(name_neuron, data=True))
#     connects = list(graph.out_edges(name_neuron, data=True))
#     counter = 0
#     type_num = []
#     for connection in connects:
#             if (connection[1] == possible_connection):
#                 counter += 1   
#     type_num = [name_neuron, counter]
#     return type_num


# def put_num_connections_xl(neurons, possible_connection):
#     update_dict()
#     whole_list = []
#     single_list = []
#     index = [0] * len(neurons)
    
#     # puts all individual connection counts into a larger list
#     for i, neuron in enumerate(neurons):
#         single_list = put_num_connections_xl_helper(neuron, possible_connection)
#         index[i] = i
#         whole_list.append(single_list)
#     return whole_list

# %%
# def script_for_num_connects(target, filter_bool, cell_type='mli'):
#     neurons_to_target = all_connections_to(target, filter_bool, cell_type)
#     filtered_to_target = list_of_neurons(neurons_to_target)
#     num_connects = put_num_connections_xl(filtered_to_target, target)
#     workbook = xl.load_workbook(r'C:\Users\regehr2\Downloads\test-book.xlsx')
#     sheet = workbook.active
#     row_number, col_number = 1, 7
#     sheet.cell(row=row_number, column=col_number, value='Neuron_ID')
#     sheet.cell(row=row_number, column=col_number + 1, value="Cell Type")
#     sheet.cell(row=row_number, column=col_number + 2, value='# Connects')
#     row_number += 1
    
#     for connect in num_connects: 
#             sheet.cell(row=row_number, column=col_number, value=connect[0])
#             sheet.cell(row=row_number, column=col_number + 1, value=CellType_dict.get(connect[0]))
#             sheet.cell(row=row_number, column=col_number + 2, value=connect[1])
#             row_number += 1
#     sheet.cell(row=row_number+ 1, column=col_number, value=target)
#     workbook.save(r'C:\Users\regehr2\Downloads\test-book.xlsx')

# %%
script_for_num_connects('pc_21', True)
# Out:
# Number of connections: 984

# %% [markdown]
# # Connections Onto pc_22

# %%
script_for_all_connects('pc_22', True)
# Out:
# Number of connections: 645
# Number of connections: 645

# %% [markdown]
# # Connections onto pc_23

# %%
script_for_all_connects('pc_23', True)
# Out:
# Number of connections: 755
# Number of connections: 755

# %% [markdown]
# # Connections onto pc_25

# %%
script_for_all_connects('pc_25', True)
# Out:
# Number of connections: 314
# Number of connections: 314
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 script_for_all_connects('pc_25', True)
#
# Cell In[5], line 6, in script_for_all_connects(target, filter_bool, cell_type)
#       4 automated_connections_list(filtered_to_target, target, r'C:\Users\regehr2\Downloads\test-book.xlsx')
#       5 script_for_num_connects(target, filter_bool, cell_type)
# ----> 6 put_num_connections_df_violin(filtered_to_target, target, 'Cell Type', 'Connections')
#
# File ~\AppData\Local\Temp\ipykernel_15032\830269155.py:42, in put_num_connections_df_violin(neurons, possible_connection, col1, col2)
#      39 colors = {'MLI 2' : '#73AF59', 'MLI 1' : '#FF00FF'}
#      41 # Creating violin plot
# ---> 42 sns.violinplot(x=col1, y=col2, data=df,  inner=None, palette=colors, scale='width')
# ...

# %% [markdown]
# # Connections onto pc_16

# %%
script_for_all_connects('pc_16', True)
# Out:
# Number of connections: 625
# Number of connections: 625

# %% [markdown]
# # Connections onto pc_3

# %%
script_for_all_connects('pc_3', True)
# Out:
# Number of connections: 551
# Number of connections: 551

# %%
script_for_all_connects('interneuron_155')
# Out:
# Number of connections: 36
# Number of connections: 36

# %% [markdown]
# # Converting functions from xl to gs

# %%
# !pip install gspread
import gspread


#credentials for service account
credentials = {
  "type": "service_account",
  "project_id": "jupyter-sheets-412818",
  "private_key_id": "e50a57eeac41bbe044b2008c2039e45320dbfa3d",
  "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email": "cole-982@jupyter-sheets-412818.iam.gserviceaccount.com",
  "client_id": "110013866146632534793",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/cole-982%40jupyter-sheets-412818.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# %%
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe


def list_or_string_no_connection_gs(name, ws_name, possible_connection, row):
    gc = gspread.service_account_from_dict(credentials)

    sh = gc.open("Synapses Data")
    ws = sh.worksheet(ws_name)
    
    if isinstance(name, str):
        # If name_neuron is a single string
        if not bool_check_connects(name, possible_connection):
            ws.append_row([name, possible_connection, 'No Connection', 'No Connection'])
            return row + 1
    else:
        # If name_neuron is a list of strings
        for n in name:
            if not bool_check_connects(n, possible_connection):
                ws.append_row([n, possible_connection, 'No Connection', 'No Connection', CellType_dict.get(n)])
                row += 1
    return row

def automate_connections_id_gs(name_neuron, possible_connection, ws_name, graph=G):
    update_dict()

    gc = gspread.service_account_from_dict(credentials)

    sh = gc.open("Synapses Data")
    ws = sh.worksheet(ws_name)

    
    # Clears existing data in the sheet
    ws.clear()

    # Sets up header row
    header_row = ['Neuron_ID', 'Connection', 'Coords of Synapse', 'Area', 'Cell Type']
    ws.append_row(header_row)

    # Gets list of all connections
    connects = list(graph.out_edges(name_neuron, data=True))

    # Goes through all neurons with no connection to possible_connection and writes no connection to the sheet
    row_number = list_or_string_no_connection_gs(name_neuron, ws_name, possible_connection, 2)
    
    # Create a list to store data
    df_list = []

    # Goes through list of connections of input(s) and filters out non-wanted connections, then writes it to sheet
    for connection in connects:
        if connection[1] == possible_connection:
            coord_str, area = str(list(connection[2].values())[0]), list(connection[2].values())[1]
            coord = coord_str.strip('(').strip(')')
            c_type = CellType_dict.get(connection[0])

            df_list.append([connection[0], connection[1], coord, area, c_type])
            
    df = pd.DataFrame(df_list, columns=header_row)
    set_with_dataframe(ws, df)
    

    return
# automate_connections_id_gs('interneuron_155', 'pc_3', "test")

# %%
# to a given xl sheet path
def automated_connections_list_gs(loNeurons, wanted_connection, ws_name):
#     for neuron in loNeurons:
        automate_connections_id_gs(loNeurons, wanted_connection, ws_name)

# %%
def put_num_connections_gs_helper(name_neuron, possible_connection, graph=G):
    
    connects = list(graph.out_edges(name_neuron, data=True))
    
    counter = 0
    for connection in connects:
        if connection[1] == possible_connection:
            counter += 1
    type_num = [name_neuron, counter]
    return type_num

def put_num_connections_gs(neurons, possible_connection):
    update_dict()
    whole_list = []
    
 
    for neuron in neurons:
        print
        single_list = put_num_connections_gs_helper(neuron[0], possible_connection)
        whole_list.append(single_list)
        
    
    return whole_list

def script_for_num_connects_gs(target, filter_bool,  ws_name, cell_type='mli'):
    update_dict()

    gc = gspread.service_account_from_dict(credentials)
    sh = gc.open("Synapses Data")
    ws = sh.worksheet(ws_name)
    
    # Sets up header row
    header_row = ['Neuron_ID', 'Cell Type', '# Connects']
    ws.append_row(header_row)
#     print('target:', target)
#     print('filter_bool:', filter_bool)
#     print('ws_name:', ws_name)
#     print('cell_type:', cell_type)

    num_connects = put_num_connections_gs(all_connections_to(target, filter_bool, cell_type), target)

    df_list = []
    # Writes data to sheet
    for connect in num_connects:
        df_list.append([connect[0], CellType_dict.get(connect[0]), connect[1]])

    df = pd.DataFrame(df_list, columns=header_row)
    df = df.drop_duplicates()
    set_with_dataframe(ws, df,  row=1, col=8)

    return

# %%
def script_for_all_connects_gs(target, ws_name, filter_bool=False, cell_type='mli'):
    neurons_to_target = all_connections_to(target, filter_bool, cell_type)
    filtered_to_target = list_of_neurons(neurons_to_target)
    automated_connections_list_gs(filtered_to_target, target, ws_name)
    script_for_num_connects_gs(target, filter_bool, ws_name, cell_type)
    put_num_connections_df_violin(filtered_to_target, target, 'Cell Type', 'Connections')

# %%
# script_for_all_connects_gs('pc_3', 'test', True)

# %%
# script_for_all_connects_gs('pc_5', 'test', True)

# %%
# Only mli 2 list
mli2_list = []
for key, value in CellType_dict.items():
    if value == 'MLI2' or value == 'MLI 2':
        mli2_list.append(key)

# mli2_list

all_pc_list = []
for nid in G.nodes:
    if ('pc' in nid and 'pcl' not in nid):
        all_pc_list.append(nid)

# %%
def filter_in_mli1(mli2_id, graph=G):
    connects = graph.in_edges(mli2_id, data=True)
    list_mli1 = []
    for connect in connects:
        if(CellType_dict.get(connect[0]) == 'MLI1' or 
           CellType_dict.get(connect[0]) == 'MLI 1' or 
           (CellType_dict.get(connect[0]) == None and "nterneuron" in connect[0])):
            list_mli1.append(connect[0])
    return list_mli1
            
def filter_in_pc(mli2_id, graph=G):
    connects = graph.in_edges(mli2_id, data=True)
    list_pc = []
    for connect in connects:
        if("pc" in connect[0] and "pcl" not in connect[0]):
            list_pc.append(connect[0])

    return list_pc

def closed_micro_circuit_from_mli2(mli2_id, graph=G):
    # list of mli1 connections (assuming that undocumented are mli1)
    connects_from_mli1 = filter_in_mli1(mli2_id, graph)
    # list of pc connections (assuming that neurons that start with pc and not pcl are pc cells)
    connects_from_pc = filter_in_pc(mli2_id, graph)
#     print('pc', connects_from_pc)
#     print('mli1 ', connects_from_mli1)
    
    for mli in connects_from_mli1:

        connections_from_mli = list(graph.out_edges(mli, data=True))

        for pc in connects_from_pc:
    
            if (connections_from_mli[1] == pc):
                print('connection from ', mli2_id, ' to ', connections_from_mli[0], ' to '
                     , pc)
                
#             else: 
#                 print(Null)

def closed_micro_circuit_from_mli2_list(mli2_list, graph=G):
    for mli2 in mli2_list:
        
        closed_micro_circuit_from_mli2(mli2)

# %%
closed_micro_circuit_from_mli2_list(mli2_list)

# %% [markdown]
# # Terrible code below must fix

# %%
def look_in_dict(d, target):
    ret = ''
    for key, value in d.items():
        if target in value: 
            ret = key
            
    return key
            

# Given a dict of connections (value is what connects to key), keep only mli2s.
def filter_mli2(lvl3_dict):
    filtered = {}
    for key, value in lvl3_dict.items():
        temp = []
        for mli in value:
#             print(mli)
            if (CellType_dict.get(mli) == 'MLI2' or CellType_dict.get(mli) == 'MLI 2' or 
            (CellType_dict.get(mli) == None and 'nterneuron' in mli)):
                temp.append(mli)
#                 print(CellType_dict.get(mli))
#                 print(mli)
#                 print('sucess')
        filtered[key] = temp
        temp = []
        
    return filtered


# Given a dict of connections (value is what connects to key), keep only pcs.
def filter_pc(list_nid):
    filtered = []
    for nid in list_nid:
        if ('pc' in nid and 'pcl' not in nid):
            filtered.append(nid)
    return filtered
#     filtered = {}
#     for key, value in lvl2_dict.items():
#         temp = []
#         for nid in value:
# #             print(mli)
#             if ('pc' in nid and 'pcl' not in nid):
#                 temp.append(nid)
# #                 print('sucess')
#         filtered[key] = temp
#         temp = []
        
#     return filtered

# given list of nid, filter for mli1
def filter_mli1(d):
    filtered = {}
    for key, value in d.items():
        temp = []
        for nid in value:
            if (CellType_dict.get(nid) == 'MLI1' or CellType_dict.get(nid) == 'MLI 1' or 
            (CellType_dict.get(nid) == None and 'nterneuron' in nid)):
                 temp.append(nid)
#                 print('sucess')
        filtered[key] = temp
        temp = []
    return filtered
#     filtered = []
#     for nid in list_nid:
#         if (CellType_dict.get(nid) == 'MLI1' or CellType_dict.get(nid) == 'MLI 1' or 
#             (CellType_dict.get(nid) == None and 'nterneuron' in nid)):
#             filtered.append(nid) 
#     return filtered




def open_microcircuit_single(mli2_id, graph=G):
    # list of mli1 connections (assuming that undocumented are mli1)
    graph = graph.reverse()
                #     connects_from_mli1 = filter_in_mli1(mli2_id, G)
    # list of pc connections (assuming that neurons that start with pc and not pcl are pc cells)
    all_pc = all_pc_list

    try:
        dict_dfs = (nx.dfs_predecessors(graph, mli2_id, 3))
#         print(dict_dfs)
    except Exception as e:
#         print(f"An error occurred: {e}")
        return
    lvl1 = [key for key, value in dict_dfs.items() if value == mli2_id]
#     print('lvl1', lvl1)
    #filter for only mli1s
    filtered_lvl1 = filter_pc(lvl1)
#     print('filtered_lvl1', filtered_lvl1)    
    lvl2_dict = {}
    for mli1 in filtered_lvl1:
        lvl2_dict[mli1] = [key for key, value in dict_dfs.items() if value == mli1]
#         lvl2.append([key for key, value in dict_dfs.items() if value == mli1])
#     print('lvl2 (value connects to key):    ', lvl2_dict)
    #   filter for only pcs
#     print(lvl2_dict)
    filtered_lvl2 = filter_mli1(lvl2_dict)
#     print('filtered_lvl2: ',filtered_lvl2)
    
    lvl3_dict = {}
    for key, value in filtered_lvl2.items():
        print('lvl2 filtered',key, value)
        for nid in value:
            connects = graph.in_edges(nid, data=True)
            temp = []
            for connect in connects:
                if connect[0] not in temp:
                    temp.append(connect[0]) 
            lvl3_dict[nid] = temp
#             print(nid, temp)
            temp = []
#             [key for key, value in dict_dfs.items() if value == nid]
#     print(lvl3_dict)
            
#     print('lvl3 dict:',lvl3_dict)
    filtered_lvl3_dict = filter_mli2(lvl3_dict)
#     print('filtered_lvl3: ',filtered_lvl3_dict)
    
    for key, value in filtered_lvl3_dict.items():
#         print(key, value)
        for mli2 in value:
            print(mli2, key, dict_dfs.get(key), mli2_id)
#             up_lvl2 =  graph.out_list
# #             look_in_dict(filtered_lvl3_dict,  CellType_dict.get(mli2))
#             up_lvl1 = [key for key, value in dict_dfs.items() if value == up_lvl2]
#             print(up_lvl2, up_lvl1)
# #             print('connections from', mli2, '(', CellType_dict.get(mli2), ')  to ', 
# #                  up_lvl2, '(', CellType_dict.get(up_lvl2), ')  to ', 
# #                  up_lvl1, '(', CellType_dict.get(up_lvl1), ')  to ', 
# #                  mli2_id, '(', CellType_dict.get(mli2_id), ')')

    

open_microcircuit_single('interneuron_256')
# Out:
# lvl2 filtered pc_31 ['interneuron_105', 'interneuron_110', 'interneuron_181', 'interneuron_220', 'interneuron_315', 'interneuron_328', 'interneuron_337', 'interneuron_338', 'interneuron_340', 'interneuron_343', 'interneuron_350', 'interneuron_352', 'interneuron_149']
# interneuron_331 interneuron_105 pc_31 interneuron_256
# interneuron_319 interneuron_105 pc_31 interneuron_256
# interneuron_179 interneuron_105 pc_31 interneuron_256
# interneuron_99 interneuron_105 pc_31 interneuron_256
# interneuron_216 interneuron_105 pc_31 interneuron_256
# interneuron_22 interneuron_105 pc_31 interneuron_256
# interneuron_131 interneuron_105 pc_31 interneuron_256
# interneuron_134 interneuron_105 pc_31 interneuron_256
# interneuron_205 interneuron_105 pc_31 interneuron_256
# interneuron_331 interneuron_110 pc_31 interneuron_256
# interneuron_319 interneuron_110 pc_31 interneuron_256
# interneuron_216 interneuron_181 pc_31 interneuron_256
# interneuron_321 interneuron_181 pc_31 interneuron_256
# ...

# %%
def open_microcircuit(mli2_id_list, graph=G):
    for mli in mli2_id_list:
        open_microcircuit_single(mli, graph)

# %%
open_microcircuit(mli2_list)
# Out:
# filtered_lvl3:  {}
# filtered_lvl3:  {}
# lvl2 filtered pc_31 ['interneuron_105', 'interneuron_110', 'interneuron_181', 'interneuron_220', 'interneuron_315', 'interneuron_328', 'interneuron_337', 'interneuron_338', 'interneuron_340', 'interneuron_343', 'interneuron_350', 'interneuron_352', 'interneuron_149']
# filtered_lvl3:  {'interneuron_105': [], 'interneuron_110': [], 'interneuron_181': [], 'interneuron_220': [], 'interneuron_315': [], 'interneuron_328': [], 'interneuron_337': [], 'interneuron_338': [], 'interneuron_340': [], 'interneuron_343': [], 'interneuron_350': [], 'interneuron_352': [], 'interneuron_149': []}
# interneuron_105 []
# interneuron_110 []
# interneuron_181 []
# interneuron_220 []
# interneuron_315 []
# interneuron_328 []
# interneuron_337 []
# interneuron_338 []
# interneuron_340 []
# interneuron_343 []
# interneuron_350 []
# interneuron_352 []
# interneuron_149 []
# lvl2 filtered pc_50 ['interneuron_142', 'interneuron_162', 'interneuron_169']
# ...

# %%
G_reversed = G.reverse()

d = (nx.dfs_predecessors(G_reversed, 'interneuron_256', 3))

# for key, value in d.items():
#     print(key, value)
    
d
# Out:
# {'interneuron_167': 'interneuron_256',
#  'interneuron_156': 'interneuron_167',
#  'interneuron_134': 'interneuron_156',
#  'interneuron_150': 'interneuron_156',
#  'interneuron_153': 'interneuron_156',
#  'interneuron_155': 'interneuron_156',
#  'interneuron_157': 'interneuron_156',
#  'interneuron_170': 'interneuron_156',
#  'interneuron_173': 'interneuron_156',
#  'interneuron_185': 'interneuron_156',
#  'interneuron_200': 'interneuron_156',
#  'interneuron_221': 'interneuron_156',
#  'interneuron_246': 'interneuron_156',
#  'interneuron_259': 'interneuron_156',
#  'interneuron_34': 'interneuron_156',
#  'interneuron_36': 'interneuron_156',
#  'interneuron_58': 'interneuron_156',
#  'interneuron_88': 'interneuron_156',
#  'interneuron_94': 'interneuron_156',
#  'pc_20': 'interneuron_156',
#  'interneuron_54': 'interneuron_156',
#  'interneuron_55': 'interneuron_156',
#  'interneuron_162': 'interneuron_167',
#  'interneuron_161': 'interneuron_162',
# ...

# %%
list(G.in_edges('interneuron_256'))
# Out:
# [('interneuron_167', 'interneuron_256'),
#  ('interneuron_168', 'interneuron_256'),
#  ('pc_21', 'interneuron_256'),
#  ('pc_21', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_10', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_13', 'interneuron_256'),
#  ('pc_20', 'interneuron_256'),
#  ('pc_20', 'interneuron_256'),
# ...

# %%
list(G.in_edges('pc_21'))
# Out:
# [('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_116', 'pc_21'),
#  ('interneuron_122', 'pc_21'),
#  ('interneuron_122', 'pc_21'),
#  ('interneuron_122', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_133', 'pc_21'),
#  ('interneuron_134', 'pc_21'),
#  ('interneuron_134', 'pc_21'),
#  ('interneuron_134', 'pc_21'),
#  ('interneuron_142', 'pc_21'),
#  ('interneuron_142', 'pc_21'),
#  ('interneuron_142', 'pc_21'),
#  ('interneuron_142', 'pc_21'),
# ...
